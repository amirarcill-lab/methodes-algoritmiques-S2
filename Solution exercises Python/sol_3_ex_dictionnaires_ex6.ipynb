# %% [markdown]
# Exercice 1 – Création d’un dictionnaire
#
# Créez un dictionnaire appelé personne qui contient les informations suivantes :
#
# -prenom
# -nom
# -age
# -ville
#
# Attribuez à chaque clé une valeur de votre choix.

# %%
pers={'prenom':'Alice','nom':'Smith', 'age':30, 'ville':'Paris'}

# %% [markdown]
# Exercice 2 – Accès aux valeurs
#
# Affichez :
#
# -le prénom de la personne
# -l’âge de la personne

# %%
pers['prenom']
# Out:
# 'Alice'

# %%
pers['age']
# Out:
# 30

# %% [markdown]
# Exercice 3 – Modification d’une valeur
#
# - Modifiez l’âge de la personne dans le dictionnaire personne.
# - Affichez ensuite le dictionnaire mis à jour.

# %%
pers['age']=14

# %%
pers
# Out:
# {'prenom': 'Alice', 'nom': 'Smith', 'age': 14, 'ville': 'Paris'}

# %% [markdown]
# Exercice 4 – Ajout d’une nouvelle information
#
# Ajoutez une nouvelle clé profession au dictionnaire personne.

# %%
pers['sport']='tennis'

# %%
pers
# Out:
# {'prenom': 'Alice',
#  'nom': 'Smith',
#  'age': 14,
#  'ville': 'Paris',
#  'sport': 'tennis'}

# %% [markdown]
# Exercice 5 – Parcourir un dictionnaire
#
# Affichez la liste des clés du dictionnaire personne.

# %%
pers.keys()
# Out:
# dict_keys(['prenom', 'nom', 'age', 'ville', 'sport'])

# %% [markdown]
# Exercice 6- Conter les mots d'un texte
#
# Créez une variable `texte` qui contient un texte d’environ **1000-2000 caracteres**, que vous pouvez copier depuis une page web de votre choix (article, blog, reportage, etc.).
#
# - comptez combien de fois chaque mot apparaît dans le texte
# - affichier les 10 mots plus utilisés
# - quels sont, à votre avis, les bonnes pratiques quand on fait cette operation pour analiser des textes?

# %%
from collections import Counter

# %% [markdown]
# Astuce : Après avoir copié le texte de Wikipédia, je suis passée par un LLM pour enlever les guillemets et autres éléments de formatage, afin de pouvoir insérer le texte comme variable.
#
# LLM, Est-ce que tu peux transformer ce texte copié de Wikipédia en une variable Python, en enlevant les guillemets et autres éléments de formatage ?

# %%
text='An incel (a portmanteau of involuntary celibate) is a member of an online subculture of mostly male and heterosexual people who define themselves as unable to find a romantic or sexual partner despite desiring one. They often blame, objectify, and denigrate women and girls as a result. The term inspired a subculture that rose to prominence during the 2010s, after being influenced by and associated with misogynist terrorists such as Elliot Rodger and Alek Minassian. The incel subculture\'s online discourse has been characterized by resentment, hostile sexism, anti-feminism, sexual objectification and dehumanization of women, misogyny, misanthropy, self-pity and self-loathing, racism, a sense of entitlement to sex, nihilism, rape culture, and the endorsement of sexual and non-sexual violence against women and the sexually active. Incels tend to blame women and feminism for their inability to find a partner; their romantic failures are often attributed to biological determinism, where women\'s preference for mating with high-status males nicknamed Chads is seen as innate and unchangeable. Incel communities have been criticized by scholars, government officials, and others for their misogyny, endorsement and encouragement of violence, and extremism. Over time the subculture has become associated with extremism and terrorism, and since 2014 there have been multiple mass killings, mostly in North America, perpetrated by self-identified incels, as well as other instances of violence or attempted violence. The Southern Poverty Law Center SPLC describes incels as part of the online male supremacist ecosystem that is included in their list of hate groups. The Global Internet Forum to Counter Terrorism GIFCT states that the incel community shares a misogynistic ideology of women as being genetically inferior to men, driven by their sexual desire to reproduce with genetically superior males, thereby excluding unattractive men such as themselves which exhibits all of the hallmarks of an extremist ideology; GIFCT states that incel beliefs combine a wish for a mythical past where all men were entitled to sex from subordinated women, a sense of predestined personal failure, and nihilism, making it a dangerous ideology. Estimates of the overall size of the subculture vary greatly, ranging from thousands to hundreds of thousands of individuals.'

# 'an incel a portmanteau of involuntary celibate is a member of an online subculture of mostly male and heterosexual people who define themselves as unable to find a romantic or sexual partner despite desiring one they often blame objectify and denigrate women and girls as a result the term inspired a subculture that rose to prominence during the 2010s after being influenced by and associated with misogynist terrorists such as elliot rodger and alek minassian the incel subcultures online discourse has been characterized by resentment hostile sexism antifeminism sexual objectification and dehumanization of women misogyny misanthropy selfpity and selfloathing racism a sense of entitlement to sex nihilism rape culture and the endorsement of sexual and nonsexual violence against women and the sexually active incels tend to blame women and feminism for their inability to find a partner their romantic failures are often attributed to biological determinism where womens preference for mating with highstatus males nicknamed chads is seen as innate and unchangeable incel communities have been criticized by scholars government officials and others for their misogyny endorsement and encouragement of violence and extremism over time the subculture has become associated with extremism and terrorism and since 2014 there have been multiple mass killings mostly in north america perpetrated by selfidentified incels as well as other instances of violence or attempted violence the southern poverty law center splc describes incels as part of the online male supremacist ecosystem that is included in their list of hate groups the global internet forum to counter terrorism gifct states that the incel community shares a misogynistic ideology of women as being genetically inferior to men driven by their sexual desire to reproduce with genetically superior males thereby excluding unattractive men such as themselves which exhibits all of the hallmarks of an extremist ideology gifct states that incel beliefs combine a wish for a mythical past where all men were entitled to sex from subordinated women a sense of predestined personal failure and nihilism making it a dangerous ideology estimates of the overall size of the subculture vary greatly ranging from thousands to hundreds of thousands of individuals'

# %% [markdown]
# #### liste de mots

# %%
listOfWords=text.split(' ') # on crée la liste des mots en séparant le texte aux espaces

# %%
len(listOfWords) # Le texte contient 353 mots
# Out:
# 353

# %% [markdown]
# #### Compter les mots

# %%
wcount=Counter(listOfWords)

# %%
wcount
# Out:
# Counter({'of': 18,
#          'and': 18,
#          'the': 13,
#          'a': 12,
#          'to': 11,
#          'as': 9,
#          'women': 6,
#          'incel': 5,
#          'by': 5,
#          'their': 5,
#          'subculture': 4,
#          'sexual': 4,
#          'that': 4,
#          'with': 4,
#          'violence': 4,
#          'for': 4,
#          'an': 3,
#          'is': 3,
#          'online': 3,
#          'been': 3,
#          'incels': 3,
#          'ideology': 3,
#          'men': 3,
#          'mostly': 2,
#          'male': 2,
#          'themselves': 2,
#          'find': 2,
#          'romantic': 2,
#          'or': 2,
#          'partner': 2,
#          'often': 2,
#          'blame': 2,
#          'being': 2,
#          'associated': 2,
#          'such': 2,
#          'has': 2,
#          'misogyny': 2,
#          'sense': 2,
#          'sex': 2,
#          'nihilism': 2,
#          'endorsement': 2,
#          'where': 2,
#          'males': 2,
#          'have': 2,
#          'extremism': 2,
#          'terrorism': 2,
#          'in': 2,
#          'gifct': 2,
#          'states': 2,
#          'genetically': 2,
#          'all': 2,
#          'from': 2,
#          'thousands': 2,
#          'portmanteau': 1,
#          'involuntary': 1,
#          'celibate': 1,
#          'member': 1,
#          'heterosexual': 1,
#          'people': 1,
#          'who': 1,
#          'define': 1,
#          'unable': 1,
#          'despite': 1,
#          'desiring': 1,
#          'one': 1,
#          'they': 1,
#          'objectify': 1,
#          'denigrate': 1,
#          'girls': 1,
#          'result': 1,
#          'term': 1,
#          'inspired': 1,
#          'rose': 1,
#          'prominence': 1,
#          'during': 1,
#          '2010s': 1,
#          'after': 1,
#          'influenced': 1,
#          'misogynist': 1,
#          'terrorists': 1,
#          'elliot': 1,
#          'rodger': 1,
#          'alek': 1,
#          'minassian': 1,
#          'subcultures': 1,
#          'discourse': 1,
#          'characterized': 1,
#          'resentment': 1,
#          'hostile': 1,
#          'sexism': 1,
#          'antifeminism': 1,
#          'objectification': 1,
#          'dehumanization': 1,
#          'misanthropy': 1,
#          'selfpity': 1,
#          'selfloathing': 1,
#          'racism': 1,
#          'entitlement': 1,
#          'rape': 1,
#          'culture': 1,
#          'nonsexual': 1,
#          'against': 1,
#          'sexually': 1,
#          'active': 1,
#          'tend': 1,
#          'feminism': 1,
#          'inability': 1,
#          'failures': 1,
#          'are': 1,
#          'attributed': 1,
#          'biological': 1,
#          'determinism': 1,
#          'womens': 1,
#          'preference': 1,
#          'mating': 1,
#          'highstatus': 1,
#          'nicknamed': 1,
#          'chads': 1,
#          'seen': 1,
#          'innate': 1,
#          'unchangeable': 1,
#          'communities': 1,
#          'criticized': 1,
#          'scholars': 1,
#          'government': 1,
#          'officials': 1,
#          'others': 1,
#          'encouragement': 1,
#          'over': 1,
#          'time': 1,
#          'become': 1,
#          'since': 1,
#          '2014': 1,
#          'there': 1,
#          'multiple': 1,
#          'mass': 1,
#          'killings': 1,
#          'north': 1,
#          'america': 1,
#          'perpetrated': 1,
#          'selfidentified': 1,
#          'well': 1,
#          'other': 1,
#          'instances': 1,
#          'attempted': 1,
#          'southern': 1,
#          'poverty': 1,
#          'law': 1,
#          'center': 1,
#          'splc': 1,
#          'describes': 1,
#          'part': 1,
#          'supremacist': 1,
#          'ecosystem': 1,
#          'included': 1,
#          'list': 1,
#          'hate': 1,
#          'groups': 1,
#          'global': 1,
#          'internet': 1,
#          'forum': 1,
#          'counter': 1,
#          'community': 1,
#          'shares': 1,
#          'misogynistic': 1,
#          'inferior': 1,
#          'driven': 1,
#          'desire': 1,
#          'reproduce': 1,
#          'superior': 1,
#          'thereby': 1,
#          'excluding': 1,
#          'unattractive': 1,
#          'which': 1,
#          'exhibits': 1,
#          'hallmarks': 1,
#          'extremist': 1,
#          'beliefs': 1,
#          'combine': 1,
#          'wish': 1,
#          'mythical': 1,
#          'past': 1,
#          'were': 1,
#          'entitled': 1,
#          'subordinated': 1,
#          'predestined': 1,
#          'personal': 1,
#          'failure': 1,
#          'making': 1,
#          'it': 1,
#          'dangerous': 1,
#          'estimates': 1,
#          'overall': 1,
#          'size': 1,
#          'vary': 1,
#          'greatly': 1,
#          'ranging': 1,
#          'hundreds': 1,
#          'individuals': 1})

# %%
# combien de fois chaque le mot 'women' apparaît dans le texte
wcount['women']
# Out:
# 6

# %% [markdown]
# #### affichier les 10 mots plus utilisés

# %%
wcount.most_common(10)
# Out:
# [('of', 18),
#  ('and', 18),
#  ('the', 13),
#  ('a', 12),
#  ('to', 11),
#  ('as', 9),
#  ('women', 6),
#  ('incel', 5),
#  ('by', 5),
#  ('their', 5)]

# %%
# une bonne pratique pour interpreter le compte des mots est d'enlever les mots vides (stop words)
# on peur retrouver des listes des mots vides en toutes langues sur internet
# ici on utilise la bibliothèque nltk pour obtenir la liste des mots vides en anglais

import nltk
nltk.download('stopwords')  # Scarica il dataset delle stopwords
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/fgargiulo/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
stop_words[:10]
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %%
# on recommence de la liste de mots on enlève les mots vides
filtered_words = [word for word in listOfWords if word not in stop_words]

# %%
wcountFiltred=Counter(filtered_words)
wcountFiltred.most_common(10)
# Out:
# [('women', 6),
#  ('incel', 5),
#  ('subculture', 4),
#  ('sexual', 4),
#  ('violence', 4),
#  ('online', 3),
#  ('incels', 3),
#  ('ideology', 3),
#  ('men', 3),
#  ('mostly', 2)]
